# %% [markdown]
# ### Importing the data

# %%
# use these links to do so:

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("churn.csv")

# %% [markdown]
# ### Understanding the data

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
# Splitting the dataset into independent and dependent variables

X = df.iloc[:, 1:18].values
y = df.iloc[:, 20].values

# %% [markdown]
# ### Data Manipulation

# %%
# Labeling the data into numberical form from string

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X[:, 0] = labelencoder.fit_transform(X[:, 0])

labelencoder_1 = LabelEncoder()
X[:, 2] = labelencoder_1.fit_transform(X[:, 2])


labelencoder_2 = LabelEncoder()
X[:, 3] = labelencoder_2.fit_transform(X[:, 3])

labelencoder_3 = LabelEncoder()
X[:, 5] = labelencoder_3.fit_transform(X[:, 5])

labelencoder_4 = LabelEncoder()
X[:, 6] = labelencoder_4.fit_transform(X[:, 6])

labelencoder_0 = LabelEncoder()
X[:, 7] = labelencoder_0.fit_transform(X[:, 7])

labelencoder_5 = LabelEncoder()
X[:, 8] = labelencoder_5.fit_transform(X[:, 8])

labelencoder_7 = LabelEncoder()
X[:, 9] = labelencoder_7.fit_transform(X[:, 9])

labelencoder_8 = LabelEncoder()
X[:, 10] = labelencoder_8.fit_transform(X[:, 10])

labelencoder_9 = LabelEncoder()
X[:, 11] = labelencoder_9.fit_transform(X[:, 11])

labelencoder_10 = LabelEncoder()
X[:, 12] = labelencoder_10.fit_transform(X[:, 12])

labelencoder_11 = LabelEncoder()
X[:, 13] = labelencoder_11.fit_transform(X[:, 13])

labelencoder_12 = LabelEncoder()
X[:, 14] = labelencoder_12.fit_transform(X[:, 14])

labelencoder_13 = LabelEncoder()
X[:, 15] = labelencoder_13.fit_transform(X[:, 15])

labelencoder_14 = LabelEncoder()
X[:, 16] = labelencoder_14.fit_transform(X[:, 16])

onehotencoder = OneHotEncoder(categorical_features = "all")
X = onehotencoder.fit_transform(X).toarray()

# Avoiding the Dummy Variable Trap
X = X[:, 1:]
# Out:
# D:\anaconda\anaconda 3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\anaconda 3\lib\site-packages\sklearn\preprocessing\_encoders.py:380: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. The passed value of 'all' is the default and can simply be removed.
#   DeprecationWarning)

# %%
# convert string to numberical form

labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)

# %% [markdown]
# ### Data Visualization

# %%
sns.scatterplot(x = "InternetService", y= "MonthlyCharges", data = df)

# %% [markdown]
# ## DSL Users
#
# 1. DSL service is cheaper than Fiber optic.
# 2. Spending of DSL users between 20-100 per month approximately.
#
# ## Fiber optic
#
# 1. Fiber optics are costly as compare to DSL services.
# 2. Users spending appx 70-120 per month approximately.

# %%
sns.scatterplot(x = "customerID", y= "MonthlyCharges" , data = df)

# %%
sns.jointplot(x="tenure", y="MonthlyCharges",data=df)
# Out:
# D:\anaconda\anaconda 3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## conclusion
# 1. Users who's tenure between 0-10 approximatly, gives large amount of monthly chargers between 18-30.
# 2. Users who's tenure between 65-70 approximatly, gives monthly charges between 65-110.

# %%
sns.pairplot(df)

# %%
sns.distplot(df["MonthlyCharges"], rug = True)
plt.xlabel('Density of poeple monthly charges')
plt.ylabel('Monthly Charges')
plt.show()

# %% [markdown]
# ## Conclusion
# 1. Less density of poeple paid between 18-30 per month.
# 2. Highly dense poeple paid between 70-110 per month.

# %% [markdown]
# ## Conclusion
#
# To increase the monthly revenue, we should target the DSL users to upgrade to fiber optic.

# %% [markdown]
# ### Implement Machine Learning Models

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
# Feature Scaling
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(X_train, y_train)
cv_score_DT =  cross_val_score(clf, X, y, cv = 10)
cv_score_DT.mean()
# Out:
# 0.7359083907344686

# %% [markdown]
# ## Random Forest Tree

# %%
from sklearn.ensemble import RandomForestClassifier
rft = RandomForestClassifier(n_estimators=10, random_state = 1)
cv_scores = cross_val_score(rft, X, y, cv=10)
cv_scores.mean()
# Out:
# 0.766289398937775

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
svc = SVC(kernel = 'linear', random_state = 1).fit(X_train, y_train)
cv_scores = cross_val_score(svc, X, y, cv = 10)
svc.score(X_test, y_test)
# Out:
# 0.7988641741599621

# %%
cv_scores.mean()
# Out:
# 0.7958231806580071

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 10).fit(X_train, y_train)
cv_scores = cross_val_score(classifier, X, y, cv = 10)

# %%
cv_scores.mean()
# Out:
# 0.7698407436628322

# %% [markdown]
# ### choosing k using for loop

# %%
for n in range(1, 50):
    classifier = KNeighborsClassifier(n_neighbors= n)
    cv_scores = cross_val_score(classifier, X, y, cv = 10 )
    print(n, cv_scores.mean())
# Out:
# 1 0.7113453928452528
# 2 0.7464169359028682
# 3 0.7411666918305355
# 4 0.7587700634565137
# 5 0.7549342294422082
# 6 0.7685665731648375
# 7 0.7621708884072407
# 8 0.7726842754708796
# 9 0.766149373471252
# 10 0.7698407436628322
# 11 0.769838524484731
# 12 0.771116532902647
# 13 0.7708316349154816
# 14 0.7726794347220579
# 15 0.7698397328090076
# 16 0.7787837654411003
# 17 0.7706903936729665
# 18 0.7785006819465806
# 19 0.7733890598388778
# 20 0.7769361648246027
# 21 0.775945274718371
# 22 0.7759442655841733
# 23 0.7736727472089314
# 24 0.7775067678770087
# 25 0.7759424510915272
# 26 0.7784988668807257
# 27 0.7783586359188263
# 28 0.7780741420439068
# 29 0.7772196512849507
# 30 0.7796356363489623
# 31 0.7763710063965523
# 32 0.779351542573827
# 33 0.7780733343926233
# 34 0.7796360358755375
# 35 0.7784968509051656
# 36 0.780487099132116
# 37 0.7782125567935337
# 38 0.7829000613792048
# 39 0.7783572243920087
# 40 0.78062712918431
# 41 0.778072525594922
# 42 0.7809132383617966
# ...

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
NB = MultinomialNB()
cv_scores_NB = cross_val_score(NB, X, y, cv = 10)
cv_scores_NB.mean()
# Out:
# 0.7253966098020549

# %% [markdown]
# ## Revisting SVM

# %%
svc = SVC(kernel = 'rbf')
cv_scores = cross_val_score(svc, X, y, cv =10)
cv_scores.mean()
# Out:
# D:\anaconda\anaconda 3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# D:\anaconda\anaconda 3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# D:\anaconda\anaconda 3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
linreg = LogisticRegression()
cv_scores_linreg = cross_val_score(linreg, X_train, y_train, cv = 10)
cv_scores_linreg.mean()
# Out:
# D:\anaconda\anaconda 3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\anaconda\anaconda 3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\anaconda\anaconda 3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\anaconda\anaconda 3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %% [markdown]
# ## Tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.backend import set_session

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

def create_model():
    model = Sequential()
    
    model.add(Dense(6, input_dim = 115, kernel_initializer = 'normal', activation = 'relu'))
    
    model.add(Dense(1, kernel_initializer = 'normal', activation='sigmoid'))
    
    model.compile(loss='binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    
    return model

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
estimator = KerasClassifier(build_fn=create_model, epochs=10, verbose=0)
cv_scores = cross_val_score(estimator, X_train, y_train, cv = 10)
cv_scores.mean()
# Out:
# WARNING:tensorflow:From D:\anaconda\anaconda 3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\anaconda\anaconda 3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 0.7931034445762635

# %% [markdown]
# ### Model Evaluation

# %%
print(f'Most suitable algorithm for this dataset is Logistic Regression with: {cv_scores_linreg.mean()}')
# Out:
# Most suitable algorithm for this dataset is Logistic Regression with: 0.800198064366187

# %%
print(f'Worst algorithm for this dataset is Naive Bayes and Decision Tree algorithm with mean ratio of: {cv_scores_NB.mean()} and {cv_score_DT.mean()}')
# Out:
# Worst algorithm for this dataset is Naive Bayes and Decision Tree algorithm with mean ratio of: 0.7253966098020549 and 0.7359083907344686

# %% [markdown]
# ### Final Conclusions

# %% [markdown]
# # Algorithm
#
# ### Logistic regression will give us best fit for this dataset. It can tell us accuratly that user will churn or not.
#
# # Business
#
# ### To increase monthly revenue, DSL users should target for upgrading their servives for fiber optic with better internet and other services.
